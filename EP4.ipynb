# %% [markdown]
# # Trabalho de Estrutura de dados - Análise de dados utilizando Pandas e Matplotlib

# %% [markdown]
# ### TALES 2018
# _______________________________________________________________________________________________________________________________
#
# A Pesquisa Internacional sobre Ensino e Aprendizagem (Talis), tradução de Teaching and Learning International Survey, é a uma pesquisa internacional coordenada pela Organização para Cooperação e Desenvolvimento Econômico (OCDE). Seu foco é avaliar o ambiente de ensino e aprendizagem, e as condições de trabalho dos professores e diretores nas escolas. No Brasil, a aplicação e o tratamento dos dados é responsabilidade do Instituto Nacional de Estudos e Pesquisas Educacionais Anísio Teixeira (Inep).
#
# A Talis é uma pesquisa direta, baseada na percepção do entrevistado. Por meio de questionários específicos para professores e diretores, ela busca saber as percepções desses dois atores sobre alguns temas relacionados ao ambiente educacional: clima escolar, desenvolvimento profissional, liderança escolar, gestão, entre outros.

# %% [markdown]
# ## Considerando a educação nos anos finais do ensino fundamental como um todo, se o investimento fosse aumentado em 5%, como você avaliaria a importância das seguintes prioridades de gastos?

# %%
import pandas as pd
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt
low_memory=False
# %matplotlib inline
pd.options.display.max_columns = 90
pd.options.display.max_rows = 90

# %%
df = pd.read_csv(r'Arquivo.csv', delimiter=',', encoding='latin-1', )

# %%
q11 = df.query("TT3G55A == 1")[["TT3G55A"]].count()
q12 = df.query("TT3G55A == 2")[["TT3G55A"]].count()
q13 = df.query("TT3G55A == 3")[["TT3G55A"]].count()
total1 = q11 + q12 + q13
medq11 = q11/total1
medq12 = q12/total1
medq13 = q13/total1
mediatotal2 = {"Questão 1": [float(medq11), float(medq12), float(medq13) ] }
MT1 = pd.DataFrame(data=mediatotal2)
labels = 'baixa importancia', 'Media importancia', 'Grande importancia'

# %%
MT1.plot(kind='pie', labels = labels, figsize=(10,10), y = ("Questão 1"), autopct = '%1.1f%%', title = ("Investir em TIC (Tecnologia de Informação e Comunicação) "), shadow = True, startangle = 90)

# %%
q21 = df.query("TT3G55B == 1")[["TT3G55B"]].count()
q22 = df.query("TT3G55B == 2")[["TT3G55B"]].count()
q23 = df.query("TT3G55B == 3")[["TT3G55B"]].count()
total2 = q21 + q22 + q23
medq21 = q21/total2
medq22 = q22/total2
medq23 = q23/total2
mediatotal2 = {"Questão 2": [float(medq21), float(medq22), float(medq23) ] }
MT2 = pd.DataFrame(data=mediatotal2)
labels = 'baixa importancia', 'Media importancia', 'Grande importancia'

# %%
MT2.plot(kind='pie', labels = labels, figsize=(10,10), y = ("Questão 2"), autopct = '%1.1f%%', title = ("Investir em materiais educativos (por exemplo, livros didáticos)"), shadow = True, startangle = 90)

# %%
q31 = df.query("TT3G55C == 1")[["TT3G55C"]].count()
q32 = df.query("TT3G55C == 2")[["TT3G55C"]].count()
q33 = df.query("TT3G55C == 3")[["TT3G55C"]].count()
total3 = q31 + q32 + q33
medq31 = q31/total3
medq32 = q32/total3
medq33 = q33/total3
mediatotal3 = {"Questão 3": [float(medq31), float(medq32), float(medq33) ] }
MT3 = pd.DataFrame(data=mediatotal3)
labels = 'baixa importancia', 'Media importancia', 'Grande importancia'

# %%
MT3.plot(kind='pie', labels = labels, figsize=(10,10), y = ("Questão 3"), autopct = '%1.1f%%', title = ("Apoiar alunos de contextos desfavorecidos ou com histórico de migração"), shadow = True, startangle = 90)

# %%
q41 = df.query("TT3G55D == 1")[["TT3G55D"]].count()
q42 = df.query("TT3G55D == 2")[["TT3G55D"]].count()
q43 = df.query("TT3G55D == 3")[["TT3G55D"]].count()
total4 = q41 + q42 + q43
medq41 = q41/total4
medq42 = q42/total4
medq43 = q43/total4
mediatotal4 = {"Questão 4": [float(medq41), float(medq42), float(medq43) ] }
MT4 = pd.DataFrame(data=mediatotal4)
labels = 'baixa importancia', 'Media importancia', 'Grande importancia'

# %% [markdown]
# ### Reduzir o tamanho das turmas recrutando mais professores
# ##### 1. De baixa importância
# ##### 2. De média importância
# ##### 3. De grande importância

# %%
MT4.plot(kind='pie', labels = labels, figsize=(10,10), y = ("Questão 4"), autopct = '%1.1f%%', title = ("Reduzir o tamanho das turmas recrutando mais professores"), shadow = True, startangle = 90)

# %%
q51 = df.query("TT3G55E == 1")[["TT3G55E"]].count()
q52 = df.query("TT3G55E == 2")[["TT3G55E"]].count()
q53 = df.query("TT3G55E == 3")[["TT3G55E"]].count()
total5 = q51 + q52 + q53
medq51 = q51/total5
medq52 = q52/total5
medq53 = q53/total5
mediatotal5 = {"Questão 5": [float(medq51), float(medq52), float(medq53) ] }
MT5 = pd.DataFrame(data=mediatotal5)
labels = 'baixa importancia', 'Media importancia', 'Grande importancia'

# %%
MT5.plot(kind='pie', labels = labels, figsize=(10,10), y = ("Questão 5"), autopct = '%1.1f%%', title = ("Melhorar os prédios e as instalações escolares"), shadow = True, startangle = 90)

# %%
q61 = df.query("TT3G55F == 1")[["TT3G55F"]].count()
q62 = df.query("TT3G55F == 2")[["TT3G55F"]].count()
q63 = df.query("TT3G55F == 3")[["TT3G55F"]].count()
total6 = q61 + q62 + q63
medq61 = q61/total6
medq62 = q62/total6
medq63 = q63/total6
mediatotal6 = {"Questão 6": [float(medq61), float(medq62), float(medq63) ] }
MT6 = pd.DataFrame(data=mediatotal6)
labels = 'baixa importancia', 'Media importancia', 'Grande importancia'

# %%
MT6.plot(kind='pie', labels = labels, figsize=(10,10), y = ("Questão 6"), autopct = '%1.1f%%', title = ("Apoiar os alunos com necessidades especiais"), shadow = True, startangle = 90)

# %%
q71 = df.query("TT3G55G == 1")[["TT3G55G"]].count()
q72 = df.query("TT3G55G == 2")[["TT3G55G"]].count()
q73 = df.query("TT3G55G == 3")[["TT3G55G"]].count()
total7 = q71 + q72 + q73
medq71 = q71/total7
medq72 = q72/total7
medq73 = q73/total7
mediatotal7 = {"Questão 7": [float(medq71), float(medq72), float(medq73)]}
MT7 = pd.DataFrame(data=mediatotal7)
labels = 'baixa importancia', 'Media importancia', 'Grande importancia'

# %%
MT7.plot(kind='pie', labels = labels, figsize=(10,10), y = ("Questão 7"), autopct = '%1.1f%%', title = ("Oferecer desenvolvimento profissional de alta qualidade para os professores"), shadow = True, startangle = 90)

# %%
q81 = df.query("TT3G55H == 1")[["TT3G55H"]].count()
q82 = df.query("TT3G55H == 2")[["TT3G55H"]].count()
q83 = df.query("TT3G55H == 3")[["TT3G55H"]].count()
total8 = q81 + q82 + q83
medq81 = q81/total8
medq82 = q82/total8
medq83 = q83/total8
mediatotal8 = {"Questão 8": [float(medq81), float(medq82), float(medq83)]}
MT8 = pd.DataFrame(data=mediatotal8)
labels = 'baixa importancia', 'Media importancia', 'Grande importancia'

# %%
MT8.plot(kind='pie', labels = labels, figsize=(10,10), y = ("Questão 8"), autopct = '%1.1f%%', title = ("Oferecer um aumento salarial para os professores"), shadow = True, startangle = 90)

# %%
q91 = df.query("TT3G55I == 1")[["TT3G55I"]].count()
q92 = df.query("TT3G55I == 2")[["TT3G55I"]].count()
q93 = df.query("TT3G55I == 3")[["TT3G55I"]].count()
total9 = q91 + q92 + q93
medq91 = q91/total9
medq92 = q92/total9
medq93 = q93/total9
mediatotal9 = {"Questão 9": [float(medq91), float(medq92), float(medq93)]}
MT9 = pd.DataFrame(data=mediatotal9)
labels = 'baixa importancia', 'Media importancia', 'Grande importancia'

# %%
MT9.plot(kind='pie', labels = labels, figsize=(10,10), y = ("Questão 9"), autopct = '%1.1f%%', title = ("Reduzir a carga de trabalho administrativo dos professores por meio da contratação de mais funcionários de apoio"), shadow = True, startangle = 90)

# %% [markdown]
# ### Conclusão
# Tallis é uma avaliação que o governo faz para saber o nível de satisfação e outras opiniões dos professores e diretores no âmbito educacional. A análise realizada foi levando em consideração o nível de prioridade que professores e diretores dão para investir em diversas esferas da educação.
# De acordo com as análises supracitadas pode -se dizer que diretores e professores consideram muito importante oferecer um aumento salarial para os professores e oferecer desenvolvimento profissional de alta qualidade para os professores pois estes contribuem no processo de aprendizagem dos alunos.
